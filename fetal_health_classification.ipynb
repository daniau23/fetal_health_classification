# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("fetal_health.csv")
df.shape
# Out:
# (2126, 22)

# %%
df.sample(n=10)
# Out:
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 1364           132.0          0.002           0.000                 0.003
# 1133           122.0          0.000           0.000                 0.011
# 1293           115.0          0.006           0.000                 0.008
# 1648           132.0          0.008           0.000                 0.009
# 492            120.0          0.012           0.085                 0.001
# 1001           129.0          0.008           0.000                 0.008
# 1165           126.0          0.009           0.000                 0.005
# 1452           148.0          0.004           0.000                 0.005
# 901            144.0          0.002           0.000                 0.007
# 1006           122.0          0.004           0.000                 0.001
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# 1364                0.003                   0.0                       0.0
# ...

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2126 non-null   float64
#  1   accelerations                                           2126 non-null   float64
#  2   fetal_movement                                          2126 non-null   float64
#  3   uterine_contractions                                    2126 non-null   float64
#  4   light_decelerations                                     2126 non-null   float64
#  5   severe_decelerations                                    2126 non-null   float64
#  6   prolongued_decelerations                                2126 non-null   float64
#  7   abnormal_short_term_variability                         2126 non-null   float64
# ...

# %%
df.describe()
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count     2126.000000    2126.000000     2126.000000           2126.000000
# mean       133.303857       0.003178        0.009481              0.004366
# std          9.840844       0.003866        0.046666              0.002946
# min        106.000000       0.000000        0.000000              0.000000
# 25%        126.000000       0.000000        0.000000              0.002000
# 50%        133.000000       0.002000        0.000000              0.004000
# 75%        140.000000       0.006000        0.003000              0.007000
# max        160.000000       0.019000        0.481000              0.015000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          2126.000000           2126.000000               2126.000000
# mean              0.001889              0.000003                  0.000159
# ...

# %%
df.isna().sum()
# Out:
# baseline value                                            0
# accelerations                                             0
# fetal_movement                                            0
# uterine_contractions                                      0
# light_decelerations                                       0
# severe_decelerations                                      0
# prolongued_decelerations                                  0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# mean_value_of_long_term_variability                       0
# histogram_width                                           0
# histogram_min                                             0
# histogram_max                                             0
# histogram_number_of_peaks                                 0
# histogram_number_of_zeroes                                0
# ...

# %%
df.duplicated().sum()
# Out:
# 13

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (2113, 22)

# %% [markdown]
# ### **Memory management**

# %%
def memory_magment(df):
    for col in df.columns:
        col_type = df[col].dtype

        if col_type != np.object or col_type != np.uint8:
            c_min = df[col].min()
            c_max = df[col].max()

            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8) # int 8
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16) # int 16
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)  # in 32
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64) # int 64
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else: 
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')    

    return df
df_memory = df.copy()
df_memory = memory_magment(df.select_dtypes(exclude=np.uint8))

# %%
df_memory.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2113 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2113 non-null   float16
#  1   accelerations                                           2113 non-null   float16
#  2   fetal_movement                                          2113 non-null   float16
#  3   uterine_contractions                                    2113 non-null   float16
#  4   light_decelerations                                     2113 non-null   float16
#  5   severe_decelerations                                    2113 non-null   float16
#  6   prolongued_decelerations                                2113 non-null   float16
#  7   abnormal_short_term_variability                         2113 non-null   float16
# ...

# %%
df_memory.fetal_health = df_memory.fetal_health.astype(int)

# %%
df_memory = memory_magment(df_memory.select_dtypes(exclude=np.uint8))

# %%
df_memory.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2113 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2113 non-null   float16
#  1   accelerations                                           2113 non-null   float16
#  2   fetal_movement                                          2113 non-null   float16
#  3   uterine_contractions                                    2113 non-null   float16
#  4   light_decelerations                                     2113 non-null   float16
#  5   severe_decelerations                                    2113 non-null   float16
#  6   prolongued_decelerations                                2113 non-null   float16
#  7   abnormal_short_term_variability                         2113 non-null   float16
# ...

# %% [markdown]
# ### **EDA**

# %%
df_eda = df_memory

# %%
df_eda.rename(columns={'baseline value':'baseline_value'},inplace=True)

# %%
df_eda.describe()
# Out:
#        baseline_value  accelerations  fetal_movement  uterine_contractions  \
# count     2113.000000    2113.000000     2113.000000           2113.000000
# mean              inf       0.003191        0.009521              0.004391
# std          9.835938       0.003876        0.046783              0.002939
# min        106.000000       0.000000        0.000000              0.000000
# 25%        126.000000       0.000000        0.000000              0.002001
# 50%        133.000000       0.002001        0.000000              0.005001
# 75%        140.000000       0.006001        0.003000              0.007000
# max        160.000000       0.018997        0.480957              0.014999
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          2113.000000           2113.000000               2113.000000
# mean              0.001904              0.000003                  0.000160
# ...

# %%
fig,ax = plt.subplots(11,2, figsize=(30,20))
ax = ax.ravel()
for index, values in enumerate(df_eda):
    sns.histplot(data=df_eda,x=values,kde=True,ax=ax[index]) 
    ax[index].set_title(f"Skewness:{np.around(df_eda[values].skew(axis=0),2)}")
    plt.subplots_adjust(wspace=0.6, hspace=1.5)

# %%
to_log = ['accelerations', 'fetal_movement',
       'uterine_contractions', 'light_decelerations',
       'prolongued_decelerations', 'abnormal_short_term_variability',
       'mean_value_of_short_term_variability',
       'percentage_of_time_with_abnormal_long_term_variability',
       'mean_value_of_long_term_variability', 'histogram_width',
       'histogram_min', 'histogram_max', 'histogram_number_of_peaks',
       'histogram_number_of_zeroes', 'histogram_mode', 'histogram_mean',
       'histogram_median', 'histogram_variance', 'histogram_tendency',
       ]

df_eda_log = df_eda.copy()
for value in to_log:
    log = (f'{value}_log')
    df_eda_log[log] = df_eda_log[value].apply(lambda x: np.log(x+1))

# %%
df_eda_log.drop(columns=to_log,inplace=True)

# %% [markdown]
# It does not seem that log made a difference, I will proceed with the application of a scaler and use of PCA to drop unimportant values

# %%
fig,ax = plt.subplots(11,2, figsize=(30,20))
ax = ax.ravel()
for index, values in enumerate(df_eda_log):
    sns.histplot(data=df_eda_log,x=values,kde=True,ax=ax[index]) 
    ax[index].set_title(f"Skewness:{np.around(df_eda_log[values].skew(axis=0),2)}")
    plt.subplots_adjust(wspace=0.6, hspace=1.5)

# %%
# sns.boxenplot(data=df_eda,y=df_eda.accelerations,x='fetal_health',palette='nipy_spectral',hue='fetal_health')

# %%
fig,ax = plt.subplots(21,figsize=(20,30))
ax = ax.ravel()

# for index, value in enumerate(df_eda.iloc[:,1:20]):
for index, value in enumerate(df_eda.iloc[:,:21]):
    sns.boxplot(data=df_eda,y=value,x='fetal_health',palette='nipy_spectral',ax=ax[index],hue='fetal_health')
    plt.subplots_adjust(wspace=0.5,hspace=1)
    sns.move_legend(
    ax[index], "lower center",
    bbox_to_anchor=(.5, 1), ncol=2, title=None, frameon=True,
    )

# %% [markdown]
# Levels of skewness
# 1. (-0.5,0.5) = lowly skewed
# 2. (-1,0, -0.5) U (0.5,1) = Moderately skewed
# 3. (-1 & beyond ) U (1 & beyond) = Highly skewed

# %%
# Horizontal orientation
# https://matplotlib.org/stable/tutorials/colors/colormaps.html
sns.set_theme()
grid_kws = {"height_ratios": (1,.05),"hspace":.3}
fig,axes =plt.subplots(2,figsize=(30,30),gridspec_kw=grid_kws)
sns.heatmap(df_eda.corr(),
            # yticklabels=1,
            # xticklabels=False,
            # cmap="RdYlGn",
            # cmap="coolwarm",
            
            cmap="rainbow", #Miscellaneous
            annot=True,
            ax=axes[0],
            vmin=-1,
            vmax=1,
            cbar=axes[1],
            cbar_kws={"orientation":"horizontal",'label':"Christmas colorbar"},
            linewidths=1
            )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### **Model Building**

# %% [markdown]
# - Scale
# - PCA
# - Model

# %%
X = df_eda.drop(columns=["fetal_health"])
y = df_eda.fetal_health

# %%
# Scaling and PCA
from sklearn.preprocessing import  StandardScaler,MinMaxScaler,RobustScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %% [markdown]
# **When using Standard Scaler()**

# %%
scaler1 = StandardScaler()
scaler2 = MinMaxScaler()
scaler3 = RobustScaler()

Xscaled1 = scaler1.fit_transform(df_eda)

# %%
pca = PCA().fit(Xscaled1)
pca_data = pca.transform(Xscaled1)

# plotting the cumulative summation of the explained variance
sns.set_theme(style='darkgrid')
fig,ax = plt.subplots(figsize=(15,9))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Variance for each components')
ax.set_title("Standard Scaler")
# Out:
# Text(0.5, 1.0, 'Standard Scaler')

# %%
exp_var_cumsum = pd.Series(np.round(pca.explained_variance_ratio_.cumsum(),4)*100)

for index,var in enumerate(exp_var_cumsum):
    print(f'If pca components is: {index}    Variance: {np.around(var,3)}')

# .90 gives about 11 components which explains the data
# Out:
# If pca components is: 0    Variance: 27.55
# If pca components is: 1    Variance: 44.22
# If pca components is: 2    Variance: 54.63
# If pca components is: 3    Variance: 61.44
# If pca components is: 4    Variance: 67.04
# If pca components is: 5    Variance: 71.72
# If pca components is: 6    Variance: 76.22
# If pca components is: 7    Variance: 80.44
# If pca components is: 8    Variance: 83.92
# If pca components is: 9    Variance: 86.95
# If pca components is: 10    Variance: 89.57
# If pca components is: 11    Variance: 91.96
# If pca components is: 12    Variance: 93.77
# If pca components is: 13    Variance: 95.33
# If pca components is: 14    Variance: 96.54
# If pca components is: 15    Variance: 97.73
# If pca components is: 16    Variance: 98.53
# If pca components is: 17    Variance: 99.12
# If pca components is: 18    Variance: 99.65
# If pca components is: 19    Variance: 99.88
# If pca components is: 20    Variance: 100.0
# ...

# %%
# Plotting the variances for each PC
fig = plt.subplots(figsize=(20,10))
PC = range(1, pca.n_components_+1)
plt.bar(PC, pca.explained_variance_ratio_, color='red')
plt.xlabel('Principal Components')
plt.xticks(rotation=1)
plt.ylabel('Variance %')
plt.xticks(PC,rotation=90)
plt.grid()

# %%
from sklearn.model_selection import GridSearchCV,train_test_split,KFold,StratifiedShuffleSplit
from sklearn.pipeline import  Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,BaggingClassifier,ExtraTreesClassifier,StackingClassifier,VotingClassifier,AdaBoostClassifier,HistGradientBoostingClassifier
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import average_precision_score,roc_auc_score,plot_precision_recall_curve,plot_roc_curve, recall_score,precision_score,f1_score

# %%
pipe1 = Pipeline([('preprocessing',StandardScaler()),('pca',PCA(.90)),('clf',KNeighborsClassifier(n_jobs=-7))])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42)

# %%
params_grid = {'clf__n_neighbors':[5,6,7],
                "clf__weights":['uniform','distance'],
                "clf__p":[1,2]}

my_cv = StratifiedShuffleSplit(n_splits=10,test_size=.2,train_size=.8)

# Try to specify the scoring for the grid
mygrid = GridSearchCV(pipe1,param_grid=params_grid,cv=my_cv, error_score="raise")
mygrid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=StratifiedShuffleSplit(n_splits=10, random_state=None, test_size=0.2,
#             train_size=0.8),
#              error_score='raise',
#              estimator=Pipeline(steps=[('preprocessing', StandardScaler()),
#                                        ('pca', PCA(n_components=0.9)),
#                                        ('clf',
#                                         KNeighborsClassifier(n_jobs=-7))]),
#              param_grid={'clf__n_neighbors': [5, 6, 7], 'clf__p': [1, 2],
#                          'clf__weights': ['uniform', 'distance']})

# %%
print(f"Best params: {mygrid.best_params_}\n")
print(f"Best estimator: {mygrid.best_estimator_}\n")
print(f"Best validation score: {mygrid.best_score_}")
# Out:
# Best params: {'clf__n_neighbors': 5, 'clf__p': 2, 'clf__weights': 'distance'}
#
# Best estimator: Pipeline(steps=[('preprocessing', StandardScaler()),
#                 ('pca', PCA(n_components=0.9)),
#                 ('clf', KNeighborsClassifier(n_jobs=-7, weights='distance'))])
#
# Best validation score: 0.895268138801262

# %%
# # Choosing the threshold
# # https://www.yourdatateacher.com/2021/06/14/are-you-still-using-0-5-as-a-threshold/
# # https://datascience.stackexchange.com/questions/89880/classification-threshold-tuning-with-gridsearchcv
# from sklearn.metrics import balanced_accuracy_score
# y_threshold_value = mygrid.predict_proba(X_train)[:,1]
# # Optimizing the threshold is equivalent to optimize a 
# # hyperparameter of your pipeline, so we do it only on the training dataset.
# threshold = []
# accuracy = []

# for p in np.unique(y_threshold_value):
#   threshold.append(p)
#   y_pred_new = (y_threshold_value >= p).astype(int)
#   accuracy.append(balanced_accuracy_score(y_train,y_pred_new))
  
# plt.scatter(threshold,accuracy)
# plt.xlabel("Threshold")
# plt.ylabel("Balanced accuracy")
# plt.show()
# print(f"This is the optimal threshold: {threshold[np.argmax(accuracy)]}")

# %%
# Classification report
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay
y_pred_train = mygrid.predict(X_train) 
y_pred_train

# 1 is automatic, automatic is the target variable 

y_pred_lower_threshold = mygrid.predict_proba(X_train) >= 0.5
y_train = y_train
sns.set_theme(style='white')
def class_report(model,y_train,y_pred_train):
    print(classification_report(y_train,y_pred_train))
    cm = confusion_matrix(y_train,y_pred_train,labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
    disp.plot()
    plt.show()


# class_report(mygrid,y_train,np.argmax(y_pred_lower_threshold, axis=1))
class_report(mygrid,y_train,y_pred_train)
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1226
#            2       1.00      1.00      1.00       219
#            3       1.00      1.00      1.00       139
#
#     accuracy                           1.00      1584
#    macro avg       1.00      1.00      1.00      1584
# weighted avg       1.00      1.00      1.00      1584

# %%
# grid_y_pred_2 = mygrid.predict_proba(X_test) > 0.6
# class_report(mygrid,y_test,np.argmax(grid_y_pred_2, axis=1))
grid_y_pred_2 = mygrid.predict(X_test) 
class_report(mygrid,y_test,grid_y_pred_2)
# print(grid_y_pred_2[:6])
# Out:
#               precision    recall  f1-score   support
#
#            1       0.94      0.97      0.95       420
#            2       0.76      0.64      0.70        73
#            3       0.89      0.86      0.87        36
#
#     accuracy                           0.91       529
#    macro avg       0.86      0.82      0.84       529
# weighted avg       0.91      0.91      0.91       529

# %% [markdown]
# ### **Something new**

# %%
# RandomForestClassifier,GradientBoostingClassifier,
# BaggingClassifier,
# ExtraTreesClassifier,
# StackingClassifier,VotingClassifier,
# AdaBoostClassifier,
# HistGradientBoostingClassifier,
# LogisticRegression,
# KNeighborsClassifier

# %%
pipe2 = Pipeline([('preprocessing',StandardScaler()),('pca',PCA(.90)),('clf',KNeighborsClassifier(n_jobs=-7))])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42)

# %%
RandomForestClassifier,GradientBoostingClassifier,
params_grid = [{'clf':[KNeighborsClassifier(n_jobs=-7)],
                'clf__n_neighbors':[5,6,7],
                "clf__weights":['uniform','distance'],
                "clf__p":[1,2]},

                {'clf':[RandomForestClassifier(n_estimators=100,random_state=42)],
                'clf__max_depth':[3,4],
                'clf__criterion':['gini','entropy'],
                'clf__min_samples_split':[2,3,4,5]},
                {
                'clf':[GradientBoostingClassifier(n_estimators=100,random_state=42)],
                'clf__max_depth':[3,4,5],
                'clf__learning_rate':[0.0001,0.01,0.1,1],
                'clf__criterion':['friedman_mse','squared_error'],
                'clf__min_samples_split':[2,3,4,5]

                }
                ]

my_cv = StratifiedShuffleSplit(n_splits=10,test_size=.2,train_size=.8)
mygrid_new = GridSearchCV(pipe2,param_grid=params_grid,cv=my_cv, error_score="raise")
mygrid_new.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=StratifiedShuffleSplit(n_splits=10, random_state=None, test_size=0.2,
#             train_size=0.8),
#              error_score='raise',
#              estimator=Pipeline(steps=[('preprocessing', StandardScaler()),
#                                        ('pca', PCA(n_components=0.9)),
#                                        ('clf',
#                                         KNeighborsClassifier(n_jobs=-7))]),
#              param_grid=[{'clf': [KNeighborsClassifier(n_jobs=-7, n_neighbors=6,
#                                                        p=1,
#                                                        weights='distance')],
#                           'clf__n_...
#                          {'clf': [RandomForestClassifier(random_state=42)],
#                           'clf__criterion': ['gini', 'entropy'],
#                           'clf__max_depth': [3, 4],
#                           'clf__min_samples_split': [2, 3, 4, 5]},
# ...

# %%
print(f"Best params: {mygrid_new.best_params_}\n") # The baseline
print(f"Best estimator: {mygrid_new.best_estimator_}\n")
print(f"Best validation score: {mygrid_new.best_score_}")
# Out:
# Best params: {'clf': KNeighborsClassifier(n_jobs=-7, n_neighbors=6, p=1, weights='distance'), 'clf__n_neighbors': 6, 'clf__p': 1, 'clf__weights': 'distance'}
#
# Best estimator: Pipeline(steps=[('preprocessing', StandardScaler()),
#                 ('pca', PCA(n_components=0.9)),
#                 ('clf',
#                  KNeighborsClassifier(n_jobs=-7, n_neighbors=6, p=1,
#                                       weights='distance'))])
#
# Best validation score: 0.8962145110410095

# %%
grid_results_new = pd.DataFrame(mygrid_new.cv_results_)
grid_results_new.to_csv('my_grid_new.csv') # exporting grid results

# %% [markdown]
# **Further training**

# %%
X = df_eda.drop(columns=["fetal_health"])
y = df_eda.fetal_health
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42)

# %%
pipe3 = Pipeline([('preprocessing',StandardScaler()),('pca',PCA(.90)),('clf',GradientBoostingClassifier(random_state=42,n_estimators=100))])
params_grids = {
               'clf__n_estimators':[100,200],
                'clf__max_depth':[3,5],
                'clf__learning_rate':[0.1,0.3,0.5],
                'clf__min_samples_split':[2]

                }
my_cv = StratifiedShuffleSplit(n_splits=10,test_size=.2,train_size=.8)                
mygrid_further = GridSearchCV(pipe3,param_grid=params_grids,cv=my_cv, error_score="raise")
mygrid_further.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=StratifiedShuffleSplit(n_splits=10, random_state=None, test_size=0.2,
#             train_size=0.8),
#              error_score='raise',
#              estimator=Pipeline(steps=[('preprocessing', StandardScaler()),
#                                        ('pca', PCA(n_components=0.9)),
#                                        ('clf',
#                                         GradientBoostingClassifier(random_state=42))]),
#              param_grid={'clf__learning_rate': [0.1, 0.3, 0.5],
#                          'clf__max_depth': [3, 5],
#                          'clf__min_samples_split': [2],
#                          'clf__n_estimators': [100, 200]})

# %%
print(f"Best params: {mygrid_further.best_params_}\n") # The baseline
print(f"Best estimator: {mygrid_further.best_estimator_}\n")
print(f"Best validation score: {mygrid_further.best_score_}")
# Out:
# Best params: {'clf__learning_rate': 0.3, 'clf__max_depth': 5, 'clf__min_samples_split': 2, 'clf__n_estimators': 100}
#
# Best estimator: Pipeline(steps=[('preprocessing', StandardScaler()),
#                 ('pca', PCA(n_components=0.9)),
#                 ('clf',
#                  GradientBoostingClassifier(learning_rate=0.3, max_depth=5,
#                                             random_state=42))])
#
# Best validation score: 0.9066246056782334

# %%
# Classification report
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay

y_pred_train_further = mygrid2.predict(X_train) 

y_train = y_train
sns.set_theme(style='white')
def class_report(model,y_train,y_pred_train):
    print(classification_report(y_train,y_pred_train))
    cm = confusion_matrix(y_train,y_pred_train,labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
    # disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
    disp.plot()
    plt.show()

class_report(mygrid_further,y_train,y_pred_train_further)
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1226
#            2       1.00      1.00      1.00       219
#            3       1.00      1.00      1.00       139
#
#     accuracy                           1.00      1584
#    macro avg       1.00      1.00      1.00      1584
# weighted avg       1.00      1.00      1.00      1584

# %%
mygrid_test_predictions_further = mygrid_further.predict(X_test) 
class_report(mygrid_further,y_test,mygrid_test_predictions_further)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.93      0.98      0.95       420
#            2       0.79      0.56      0.66        73
#            3       0.81      0.83      0.82        36
#
#     accuracy                           0.91       529
#    macro avg       0.84      0.79      0.81       529
# weighted avg       0.90      0.91      0.90       529

# %%
precision_score(y_test,mygrid_test_predictions_further, average="weighted")
# Out:
# 0.903800600870544

# %%
recall_score(y_test,mygrid_test_predictions_further, average="weighted")
# Out:
# 0.9092627599243857

# %%
f1_score(y_test,mygrid_test_predictions_further, average="micro")
# Out:
# 0.9092627599243857

# %%
from sklearn.metrics import matthews_corrcoef

matthews_corrcoef(y_test, mygrid_test_predictions_further) # for multiclass evaluation a score above 0.7 is considered good
# Out:
# 0.7233961014627618

# %% [markdown]
# **Precision Recall Curve for Multiclass**

# %%
#Reference: https://stackoverflow.com/questions/56090541/how-to-plot-precision-and-recall-of-multiclass-classifier
from sklearn.multiclass import  OneVsRestClassifier
from sklearn.preprocessing import label_binarize



y = label_binarize(y, classes=[1,2,3])
n_classes = y.shape[1]

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    random_state = 42)

clf_further = OneVsRestClassifier(GradientBoostingClassifier(learning_rate=0.3, max_depth=5,
                                            n_estimators=200,
                                            random_state=42))
clf_further.fit(X_train, y_train)

# y_prediction_proba = clf.predict_proba(X_test) > 0.3
y_prediction_proba_further = clf_further.predict_proba(X_test) 

# def precision_recall_form(model):
#     classifier = OneVsRestClassifier(model)
#     classifier.fit(X_train,y_train)
#     y_score = classifier.predict_proba(X_test)
#     return y_score

# %%
from sklearn.metrics import precision_recall_curve,roc_curve

# %%
# For each class 
precision = dict()
recall = dict()

y_test = y_test
def precision_recall_plot(value,y_test):
    for i in range(n_classes):
        precision[i], recall[i], threshold = precision_recall_curve(y_test[:,i], 
                                                        value[:,i])
        plt.plot(precision[i],recall[i],lw=2, label= "class {}".format(i))

    plt.xlabel("precision")
    plt.ylabel("recall")
    plt.legend(loc="best")
    plt.title("Precision-recall curve of iris multiclass; dataset")
    plt.show()
    average_precision = average_precision_score(y_test,value, average='micro')
    print("Average precision score, micro-averaged over all classes: {:.3f}".format(average_precision))

# %%
precision_recall_plot(y_prediction_proba_further,y_test)
# Out:
# Average precision score, micro-averaged over all classes: 0.990

# %%
fpr = dict()
tpr = dict()

def roc_curve_plot(value,y_test):
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:,i], 
                                                    value[:,i])
        plt.plot(fpr[i], tpr[i], lw=2, label= "class {}".format(i))

    plt.xlabel("false positive rate")
    plt.ylabel("true positive rate")
    plt.legend(loc="best")
    plt.title("ROC curve of multiclass; dataset")
    plt.show()
    roc_auc_scoring_macro_ovr = roc_auc_score(y_test,value, multi_class="OvR",average='macro')
    roc_auc_scoring_weighted_ovr = roc_auc_score(y_test,value, multi_class="OvR",average='weighted')
    print("AUC score using OvR, macro-averaged over all classes: {:.3f}\nWeighted-averaged over all classes: {:.3f}"
    .format(roc_auc_scoring_macro_ovr,roc_auc_scoring_weighted_ovr))

# %%
roc_curve_plot(y_prediction_proba_further,y_test)
# Out:
# AUC score using OvR, macro-averaged over all classes: 0.981
# Weighted-averaged over all classes: 0.984

# %% [markdown]
# ### **XGB**

# %%
import xgboost as xgb
# https://xgboost.readthedocs.io/en/stable/python/python_api.html?highlight=XGBClassifier#xgboost.XGBClassifier

# %%
X = df_eda.drop(columns=["fetal_health"])
y = df_eda.fetal_health
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    random_state = 42)

# %%
pipe4 = Pipeline([('preprocessing',StandardScaler()),('pca',PCA(.90)),('clf',xgb.XGBClassifier(random_state=42,n_estimators=100))])
params_grids = {
               'clf__n_estimators':[100,200],
                'clf__max_depth':[5],
                'clf__learning_rate':[0.1,0.3,0.5],
                'clf__tree_method':['approx','exact'],
                'clf__grow_policy':['depthwise', 'lossguide'],
                'clf__max_leaves':[5]
                }
my_cv = StratifiedShuffleSplit(n_splits=10,test_size=.2,train_size=.8)                
mygrid_xgb = GridSearchCV(pipe4,param_grid=params_grids,cv=my_cv, error_score="raise")
mygrid_xgb.fit(X_train,y_train)
# Out:
# [21:22:06] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:22:06] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:22:07] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
print(f"Best params: {mygrid_xgb.best_params_}\n") # The baseline
print(f"Best estimator: {mygrid_xgb.best_estimator_}\n")
print(f"Best validation score: {mygrid_xgb.best_score_}")
# Out:
# Best params: {'clf__grow_policy': 'depthwise', 'clf__learning_rate': 0.5, 'clf__max_depth': 5, 'clf__max_leaves': 5, 'clf__n_estimators': 100, 'clf__tree_method': 'approx'}
#
# Best estimator: Pipeline(steps=[('preprocessing', StandardScaler()),
#                 ('pca', PCA(n_components=0.9)),
#                 ('clf',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, gpu_id=-1,
#                                grow_policy='depthwise', importance_type='gain',
#                                interaction_constraints='', learning_rate=0.5,
#                                max_delta_step=0, max_depth=5, max_leaves=5,
#                                min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=100,
#                                n_jobs=8, num_parallel_tree=1,
# ...

# %%
# Classification report
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay
y_pred_train_xgb = mygrid_xgb.predict(X_train) 
y_pred_train_xgb


y_train = y_train
sns.set_theme(style='white')
def class_report(model,y_train,y_pred_train):
    print(classification_report(y_train,y_pred_train))
    cm = confusion_matrix(y_train,y_pred_train,labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
    disp.plot()
    plt.show()


class_report(mygrid_xgb,y_train,y_pred_train_xgb)
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1226
#            2       1.00      1.00      1.00       219
#            3       1.00      1.00      1.00       139
#
#     accuracy                           1.00      1584
#    macro avg       1.00      1.00      1.00      1584
# weighted avg       1.00      1.00      1.00      1584

# %%
mygrid_test_predictions_xgb = mygrid_xgb.predict(X_test) 
class_report(mygrid_xgb,y_test,mygrid_test_predictions_xgb)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.93      0.97      0.95       420
#            2       0.80      0.59      0.68        73
#            3       0.84      0.86      0.85        36
#
#     accuracy                           0.91       529
#    macro avg       0.86      0.81      0.83       529
# weighted avg       0.91      0.91      0.91       529

# %%
precision_score(y_test,mygrid_test_predictions_xgb, average="weighted")
# Out:
# 0.9082865266799803

# %%
recall_score(y_test,mygrid_test_predictions_xgb, average="weighted")
# Out:
# 0.9130434782608695

# %%
f1_score(y_test,mygrid_test_predictions_xgb, average="micro")
# Out:
# 0.9130434782608695

# %%
from sklearn.metrics import matthews_corrcoef

matthews_corrcoef(y_test, mygrid_test_predictions_xgb) # for multiclass evaluation a score above 0.7 is considered good
# Out:
# 0.7361548939131658

# %% [markdown]
# **Precision Recall Curve for Multiclass**

# %%
# Reference: https://stackoverflow.com/questions/56090541/how-to-plot-precision-and-recall-of-multiclass-classifier
from sklearn.multiclass import  OneVsRestClassifier
from sklearn.preprocessing import label_binarize
from sklearn.metrics import precision_recall_curve,roc_curve

y = label_binarize(y, classes=[1,2,3])
n_classes = y.shape[1]

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    random_state = 42)

clf = OneVsRestClassifier(xgb.XGBClassifier(grow_policy='depthwise', 
                                            learning_rate=0.3, 
                                            max_depth=5, 
                                            max_leaves=5, 
                                            n_estimators=200, 
                                            tree_method='approx'))
clf.fit(X_train, y_train)
X_test = X_test.astype(int)
# y_prediction_proba = clf.predict_proba(X_test) > 0.3
y_prediction_proba_xgb = clf.predict_proba(X_test)
# Out:
# [21:26:02] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:26:02] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:26:03] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
# For each class 
precision = dict()
recall = dict()

y_test = y_test
def precision_recall_plot(value,y_test):
    for i in range(n_classes):
        precision[i], recall[i], threshold = precision_recall_curve(y_test[:,i], 
                                                        value[:,i])
        plt.plot(precision[i],recall[i],lw=2, label= "class {}".format(i))


    plt.xlabel("precision")
    plt.ylabel("recall")
    plt.legend(loc="best")
    plt.title("Precision-recall curve of multiclass; dataset")
    plt.show()
    average_precision = average_precision_score(y_test,value, average='micro')
    print("Average precision score, micro-averaged over all classes: {:.3f}".format(average_precision))

# %%
precision_recall_plot(y_prediction_proba_xgb,y_test)
# Out:
# Average precision score, micro-averaged over all classes: 0.936

# %%
fpr = dict()
tpr = dict()

def roc_curve_plot(value,y_test):
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:,i], 
                                                    value[:,i])
        plt.plot(fpr[i], tpr[i], lw=2, label= "class {}".format(i))

    plt.xlabel("false positive rate")
    plt.ylabel("true positive rate")
    plt.legend(loc="best")
    plt.title("ROC curve of multiclass; dataset")
    plt.show()
    roc_auc_scoring_macro_ovr = roc_auc_score(y_test,value, multi_class="OvR",average='macro')
    roc_auc_scoring_weighted_ovr = roc_auc_score(y_test,value, multi_class="OvR",average='weighted')
    print("AUC score using OvR, macro-averaged over all classes: {:.3f}\nWeighted-averaged over all classes: {:.3f}"
    .format(roc_auc_scoring_macro_ovr,roc_auc_scoring_weighted_ovr))

# %%
roc_curve_plot(y_prediction_proba_xgb,y_test)
# Out:
# AUC score using OvR, macro-averaged over all classes: 0.953
# Weighted-averaged over all classes: 0.937

# %%
# This is for the training set
model= ['XGB','Gradient Boosting Classifier','KNN']
prediction_score= [mygrid_xgb.best_score_,mygrid_further.best_score_,mygrid.best_score_]

model_comparison = {"model": model, "prediction_score": prediction_score}
comparison = pd.DataFrame(model_comparison)
comparison
# Out:
#                           model  prediction_score
# 0                           XGB          0.898107
# 1  Gradient Boosting Classifier          0.906625
# 2                           KNN          0.895268

# %% [markdown]
# ### **When using Robust Scaler()**

# %%
X = df_eda.drop(columns=["fetal_health"])
y = df_eda.fetal_health
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    random_state = 42)

# %%
scaler1 = StandardScaler()
scaler2 = MinMaxScaler()
scaler3 = RobustScaler()

Xscaled2 = scaler2.fit_transform(df_eda)

# %%
pca = PCA().fit(Xscaled2)
pca_data = pca.transform(Xscaled2)

# plotting the cumulative summation of the explained variance
sns.set_theme(style='darkgrid')
fig,ax = plt.subplots(figsize=(15,9))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Variance for each components')
ax.set_title("Robust Scaler")
# Out:
# Text(0.5, 1.0, 'Robust Scaler')

# %%
exp_var_cumsum = pd.Series(np.round(pca.explained_variance_ratio_.cumsum(),4)*100)

for index,var in enumerate(exp_var_cumsum):
    print(f'If pca components is: {index}    Variance: {np.around(var,3)}')

# .90 gives about 7 components which explains the data
# Out:
# If pca components is: 0    Variance: 29.19
# If pca components is: 1    Variance: 48.49
# If pca components is: 2    Variance: 63.98
# If pca components is: 3    Variance: 73.11
# If pca components is: 4    Variance: 78.81
# If pca components is: 5    Variance: 83.21
# If pca components is: 6    Variance: 87.36
# If pca components is: 7    Variance: 90.19
# If pca components is: 8    Variance: 92.98
# If pca components is: 9    Variance: 94.44
# If pca components is: 10    Variance: 95.67
# If pca components is: 11    Variance: 96.6
# If pca components is: 12    Variance: 97.41
# If pca components is: 13    Variance: 98.12
# If pca components is: 14    Variance: 98.74
# If pca components is: 15    Variance: 99.31
# If pca components is: 16    Variance: 99.77
# If pca components is: 17    Variance: 99.93
# If pca components is: 18    Variance: 100.0
# If pca components is: 19    Variance: 100.0
# If pca components is: 20    Variance: 100.0
# ...

# %%
# Plotting the variances for each PC
fig = plt.subplots(figsize=(20,10))
PC = range(1, pca.n_components_+1)
plt.bar(PC, pca.explained_variance_ratio_, color='red')
plt.xlabel('Principal Components')
plt.xticks(rotation=1)
plt.ylabel('Variance %')
plt.xticks(PC,rotation=90)
plt.grid()

# %%
from sklearn.model_selection import GridSearchCV,train_test_split,KFold,StratifiedShuffleSplit
from sklearn.pipeline import  Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,BaggingClassifier,ExtraTreesClassifier,StackingClassifier,VotingClassifier,AdaBoostClassifier,HistGradientBoostingClassifier
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import average_precision_score,roc_auc_score,plot_precision_recall_curve,plot_roc_curve, recall_score,precision_score,f1_score

# %%
pipe1_robust = Pipeline([('preprocessing',RobustScaler()),('pca',PCA(.90)),('clf',KNeighborsClassifier(n_jobs=-7))])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42)

# %%
params_grid = {'clf__n_neighbors':[5,6,7],
                "clf__weights":['uniform','distance'],
                "clf__p":[1,2]}

my_cv = StratifiedShuffleSplit(n_splits=10,test_size=.2,train_size=.8)

# Try to specify the scoring for the grid
mygrid_robust = GridSearchCV(pipe1_robust,param_grid=params_grid,cv=my_cv, error_score="raise")
mygrid_robust.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=StratifiedShuffleSplit(n_splits=10, random_state=None, test_size=0.2,
#             train_size=0.8),
#              error_score='raise',
#              estimator=Pipeline(steps=[('preprocessing', RobustScaler()),
#                                        ('pca', PCA(n_components=0.9)),
#                                        ('clf',
#                                         KNeighborsClassifier(n_jobs=-7))]),
#              param_grid={'clf__n_neighbors': [5, 6, 7], 'clf__p': [1, 2],
#                          'clf__weights': ['uniform', 'distance']})

# %%
print(f"Best params: {mygrid_robust.best_params_}\n")
print(f"Best estimator: {mygrid_robust.best_estimator_}\n")
print(f"Best validation score: {mygrid_robust.best_score_}")
# Out:
# Best params: {'clf__n_neighbors': 6, 'clf__p': 1, 'clf__weights': 'uniform'}
#
# Best estimator: Pipeline(steps=[('preprocessing', RobustScaler()),
#                 ('pca', PCA(n_components=0.9)),
#                 ('clf', KNeighborsClassifier(n_jobs=-7, n_neighbors=6, p=1))])
#
# Best validation score: 0.8022082018927446

# %%
# # Choosing the threshold
# # https://www.yourdatateacher.com/2021/06/14/are-you-still-using-0-5-as-a-threshold/
# # https://datascience.stackexchange.com/questions/89880/classification-threshold-tuning-with-gridsearchcv
# from sklearn.metrics import balanced_accuracy_score
# y_threshold_value = mygrid.predict_proba(X_train)[:,1]
# # Optimizing the threshold is equivalent to optimize a 
# # hyperparameter of your pipeline, so we do it only on the training dataset.
# threshold = []
# accuracy = []

# for p in np.unique(y_threshold_value):
#   threshold.append(p)
#   y_pred_new = (y_threshold_value >= p).astype(int)
#   accuracy.append(balanced_accuracy_score(y_train,y_pred_new))
  
# plt.scatter(threshold,accuracy)
# plt.xlabel("Threshold")
# plt.ylabel("Balanced accuracy")
# plt.show()
# print(f"This is the optimal threshold: {threshold[np.argmax(accuracy)]}")

# %%
# Classification report
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay
y_pred_train_robust = mygrid_robust.predict(X_train) 
y_pred_train


y_pred_lower_threshold = mygrid.predict_proba(X_train) >= 0.5
y_train = y_train
sns.set_theme(style='white')
def class_report(model,y_train,y_pred_train):
    print(classification_report(y_train,y_pred_train))
    cm = confusion_matrix(y_train,y_pred_train,labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
    disp.plot()
    plt.show()


# class_report(mygrid,y_train,np.argmax(y_pred_lower_threshold, axis=1))
class_report(mygrid_robust,y_train,y_pred_train_robust)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.85      0.98      0.91      1226
#            2       0.69      0.32      0.44       219
#            3       0.76      0.45      0.56       139
#
#     accuracy                           0.84      1584
#    macro avg       0.77      0.58      0.64      1584
# weighted avg       0.82      0.84      0.82      1584

# %%
# grid_y_pred_2 = mygrid.predict_proba(X_test) > 0.6
# class_report(mygrid,y_test,np.argmax(grid_y_pred_2, axis=1))
grid_y_pred_2_robust = mygrid_robust.predict(X_test) 
class_report(mygrid_robust,y_test,grid_y_pred_2_robust)
# print(grid_y_pred_2[:6])
# Out:
#               precision    recall  f1-score   support
#
#            1       0.84      0.95      0.89       420
#            2       0.41      0.19      0.26        73
#            3       0.61      0.39      0.47        36
#
#     accuracy                           0.80       529
#    macro avg       0.62      0.51      0.54       529
# weighted avg       0.77      0.80      0.78       529

# %% [markdown]
# ### **Something new**

# %%
# RandomForestClassifier,GradientBoostingClassifier,
# BaggingClassifier,
# ExtraTreesClassifier,
# StackingClassifier,VotingClassifier,
# AdaBoostClassifier,
# HistGradientBoostingClassifier,
# LogisticRegression,
# KNeighborsClassifier

# %%
pipe2_robust = Pipeline([('preprocessing',RobustScaler()),('pca',PCA(.90)),('clf',KNeighborsClassifier(n_jobs=-7))])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42)

# %%
RandomForestClassifier,GradientBoostingClassifier,
params_grid = [{'clf':[KNeighborsClassifier(n_jobs=-7)],
                'clf__n_neighbors':[5,6,7],
                "clf__weights":['uniform','distance'],
                "clf__p":[1,2]},

                {'clf':[RandomForestClassifier(n_estimators=100,random_state=42)],
                'clf__max_depth':[3,4],
                'clf__criterion':['gini','entropy'],
                'clf__min_samples_split':[2,3,4,5]},
                {
                'clf':[GradientBoostingClassifier(n_estimators=100,random_state=42)],
                'clf__max_depth':[3,4,5],
                'clf__learning_rate':[0.0001,0.01,0.1,1],
                'clf__criterion':['friedman_mse','squared_error'],
                'clf__min_samples_split':[2,3,4,5]

                }
                ]

my_cv = StratifiedShuffleSplit(n_splits=10,test_size=.2,train_size=.8)
mygrid_new_robust = GridSearchCV(pipe2_robust,param_grid=params_grid,cv=my_cv, error_score="raise")
mygrid_new_robust.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=StratifiedShuffleSplit(n_splits=10, random_state=None, test_size=0.2,
#             train_size=0.8),
#              error_score='raise',
#              estimator=Pipeline(steps=[('preprocessing', RobustScaler()),
#                                        ('pca', PCA(n_components=0.9)),
#                                        ('clf',
#                                         KNeighborsClassifier(n_jobs=-7))]),
#              param_grid=[{'clf': [KNeighborsClassifier(n_jobs=-7, n_neighbors=6,
#                                                        p=1)],
#                           'clf__n_neighbors': [5, 6, 7], 'c...
#                          {'clf': [RandomForestClassifier(random_state=42)],
#                           'clf__criterion': ['gini', 'entropy'],
#                           'clf__max_depth': [3, 4],
#                           'clf__min_samples_split': [2, 3, 4, 5]},
#                          {'clf': [GradientBoostingClassifier(random_state=42)],
# ...

# %%
print(f"Best params: {mygrid_new_robust.best_params_}\n") # The baseline
print(f"Best estimator: {mygrid_new_robust.best_estimator_}\n")
print(f"Best validation score: {mygrid_new_robust.best_score_}")
# Out:
# Best params: {'clf': KNeighborsClassifier(n_jobs=-7, n_neighbors=6, p=1), 'clf__n_neighbors': 6, 'clf__p': 1, 'clf__weights': 'uniform'}
#
# Best estimator: Pipeline(steps=[('preprocessing', RobustScaler()),
#                 ('pca', PCA(n_components=0.9)),
#                 ('clf', KNeighborsClassifier(n_jobs=-7, n_neighbors=6, p=1))])
#
# Best validation score: 0.8157728706624606

# %%
grid_results_new = pd.DataFrame(mygrid_new.cv_results_)
grid_results_new.to_csv('my_grid_new.csv') # exporting grid results

# %% [markdown]
# **Further training**

# %%
X = df_eda.drop(columns=["fetal_health"])
y = df_eda.fetal_health
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42)

# %%
pipe3_robust = Pipeline([('preprocessing',RobustScaler()),('pca',PCA(.90)),('clf',GradientBoostingClassifier(random_state=42,n_estimators=100))])
params_grids = {
               'clf__n_estimators':[100,200],
                'clf__max_depth':[3,5],
                'clf__learning_rate':[0.1,0.3,0.5],
                'clf__min_samples_split':[2]

                }
my_cv = StratifiedShuffleSplit(n_splits=10,test_size=.2,train_size=.8)                
mygrid_further_robust = GridSearchCV(pipe3_robust,param_grid=params_grids,cv=my_cv, error_score="raise")
mygrid_further_robust.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=StratifiedShuffleSplit(n_splits=10, random_state=None, test_size=0.2,
#             train_size=0.8),
#              error_score='raise',
#              estimator=Pipeline(steps=[('preprocessing', RobustScaler()),
#                                        ('pca', PCA(n_components=0.9)),
#                                        ('clf',
#                                         GradientBoostingClassifier(random_state=42))]),
#              param_grid={'clf__learning_rate': [0.1, 0.3, 0.5],
#                          'clf__max_depth': [3, 5],
#                          'clf__min_samples_split': [2],
#                          'clf__n_estimators': [100, 200]})

# %%
print(f"Best params: {mygrid_further_robust.best_params_}\n") # The baseline
print(f"Best estimator: {mygrid_further_robust.best_estimator_}\n")
print(f"Best validation score: {mygrid_further_robust.best_score_}")
# Out:
# Best params: {'clf__learning_rate': 0.1, 'clf__max_depth': 3, 'clf__min_samples_split': 2, 'clf__n_estimators': 100}
#
# Best estimator: Pipeline(steps=[('preprocessing', RobustScaler()),
#                 ('pca', PCA(n_components=0.9)),
#                 ('clf', GradientBoostingClassifier(random_state=42))])
#
# Best validation score: 0.8018927444794952

# %%
# Classification report
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay

y_pred_train_further_robust = mygrid2.predict(X_train) 

y_train = y_train
sns.set_theme(style='white')
def class_report(model,y_train,y_pred_train):
    print(classification_report(y_train,y_pred_train))
    cm = confusion_matrix(y_train,y_pred_train,labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
    # disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
    disp.plot()
    plt.show()

class_report(mygrid_further_robust,y_train,y_pred_train_further_robust)
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1226
#            2       1.00      1.00      1.00       219
#            3       1.00      1.00      1.00       139
#
#     accuracy                           1.00      1584
#    macro avg       1.00      1.00      1.00      1584
# weighted avg       1.00      1.00      1.00      1584

# %%
mygrid_test_predictions_further_robust = mygrid_further_robust.predict(X_test) 
class_report(mygrid_further_robust,y_test,mygrid_test_predictions_further_robust)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.85      0.96      0.90       420
#            2       0.52      0.21      0.29        73
#            3       0.52      0.36      0.43        36
#
#     accuracy                           0.81       529
#    macro avg       0.63      0.51      0.54       529
# weighted avg       0.78      0.81      0.78       529

# %%
precision_score(y_test,mygrid_test_predictions_further_robust, average="weighted")
# Out:
# 0.780369494886424

# %%
recall_score(y_test,mygrid_test_predictions_further_robust, average="weighted")
# Out:
# 0.8147448015122873

# %%
f1_score(y_test,mygrid_test_predictions_further_robust, average="micro")
# Out:
# 0.8147448015122873

# %%
from sklearn.metrics import matthews_corrcoef

matthews_corrcoef(y_test, mygrid_test_predictions_further_robust) # for multiclass evaluation a score above 0.7 is considered good
# Out:
# 0.35657321071604914

# %% [markdown]
# **Precision Recall Curve for Multiclass**

# %%
#Reference: https://stackoverflow.com/questions/56090541/how-to-plot-precision-and-recall-of-multiclass-classifier
from sklearn.multiclass import  OneVsRestClassifier
from sklearn.preprocessing import label_binarize



y = label_binarize(y, classes=[1,2,3])
n_classes = y.shape[1]

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    random_state = 42)

clf_further_robust = OneVsRestClassifier(GradientBoostingClassifier(learning_rate=0.3, max_depth=5,
                                            n_estimators=200,
                                            random_state=42))
clf_further_robust.fit(X_train, y_train)

# y_prediction_proba = clf.predict_proba(X_test) > 0.3
y_prediction_proba_further_robust = clf_further_robust.predict_proba(X_test) 

# def precision_recall_form(model):
#     classifier = OneVsRestClassifier(model)
#     classifier.fit(X_train,y_train)
#     y_score = classifier.predict_proba(X_test)
#     return y_score

# %%
from sklearn.metrics import precision_recall_curve,roc_curve

# %%
# For each class 
precision = dict()
recall = dict()

y_test = y_test
def precision_recall_plot(value,y_test):
    for i in range(n_classes):
        precision[i], recall[i], threshold = precision_recall_curve(y_test[:,i], 
                                                        value[:,i])
        plt.plot(precision[i],recall[i],lw=2, label= "class {}".format(i))

    plt.xlabel("precision")
    plt.ylabel("recall")
    plt.legend(loc="best")
    plt.title("Precision-recall curve of iris multiclass; dataset")
    plt.show()
    average_precision = average_precision_score(y_test,value, average='micro')
    print("Average precision score, micro-averaged over all classes: {:.3f}".format(average_precision))

# %%
precision_recall_plot(y_prediction_proba_further_robust,y_test)
# Out:
# Average precision score, micro-averaged over all classes: 0.990

# %%
fpr = dict()
tpr = dict()

def roc_curve_plot(value,y_test):
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:,i], 
                                                    value[:,i])
        plt.plot(fpr[i], tpr[i], lw=2, label= "class {}".format(i))

    plt.xlabel("false positive rate")
    plt.ylabel("true positive rate")
    plt.legend(loc="best")
    plt.title("ROC curve of multiclass; dataset")
    plt.show()
    roc_auc_scoring_macro_ovr = roc_auc_score(y_test,value, multi_class="OvR",average='macro')
    roc_auc_scoring_weighted_ovr = roc_auc_score(y_test,value, multi_class="OvR",average='weighted')
    print("AUC score using OvR, macro-averaged over all classes: {:.3f}\nWeighted-averaged over all classes: {:.3f}"
    .format(roc_auc_scoring_macro_ovr,roc_auc_scoring_weighted_ovr))

# %%
roc_curve_plot(y_prediction_proba_further_robust,y_test)
# Out:
# AUC score using OvR, macro-averaged over all classes: 0.981
# Weighted-averaged over all classes: 0.984

# %% [markdown]
# ### **XGB**

# %%
import xgboost as xgb
# https://xgboost.readthedocs.io/en/stable/python/python_api.html?highlight=XGBClassifier#xgboost.XGBClassifier

# %%
X = df_eda.drop(columns=["fetal_health"])
y = df_eda.fetal_health
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    random_state = 42)

# %%
pipe4_robust = Pipeline([('preprocessing',RobustScaler()),('pca',PCA(.90)),('clf',xgb.XGBClassifier(random_state=42,n_estimators=100))])
params_grids = {
               'clf__n_estimators':[100,200],
                'clf__max_depth':[5],
                'clf__learning_rate':[0.1,0.3,0.5],
                'clf__tree_method':['approx','exact'],
                'clf__grow_policy':['depthwise', 'lossguide'],
                'clf__max_leaves':[5]
                }
my_cv = StratifiedShuffleSplit(n_splits=10,test_size=.2,train_size=.8)                
mygrid_xgb_robust = GridSearchCV(pipe4_robust,param_grid=params_grids,cv=my_cv, error_score="raise")
mygrid_xgb_robust.fit(X_train,y_train)
# Out:
# [22:19:32] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [22:19:33] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [22:19:33] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
print(f"Best params: {mygrid_xgb_robust.best_params_}\n") # The baseline
print(f"Best estimator: {mygrid_xgb_robust.best_estimator_}\n")
print(f"Best validation score: {mygrid_xgb_robust.best_score_}")
# Out:
# Best params: {'clf__grow_policy': 'depthwise', 'clf__learning_rate': 0.1, 'clf__max_depth': 5, 'clf__max_leaves': 5, 'clf__n_estimators': 100, 'clf__tree_method': 'approx'}
#
# Best estimator: Pipeline(steps=[('preprocessing', RobustScaler()),
#                 ('pca', PCA(n_components=0.9)),
#                 ('clf',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, gpu_id=-1,
#                                grow_policy='depthwise', importance_type='gain',
#                                interaction_constraints='', learning_rate=0.1,
#                                max_delta_step=0, max_depth=5, max_leaves=5,
#                                min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=100,
#                                n_jobs=8, num_parallel_tree=1,
# ...

# %%
# Classification report
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay
y_pred_train_xgb_robust = mygrid_xgb_robust.predict(X_train) 



y_train = y_train
sns.set_theme(style='white')
def class_report(model,y_train,y_pred_train):
    print(classification_report(y_train,y_pred_train))
    cm = confusion_matrix(y_train,y_pred_train,labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
    disp.plot()
    plt.show()


class_report(mygrid_xgb_robust,y_train,y_pred_train_xgb_robust)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.84      0.98      0.91      1226
#            2       0.67      0.27      0.39       219
#            3       0.77      0.42      0.54       139
#
#     accuracy                           0.83      1584
#    macro avg       0.76      0.56      0.61      1584
# weighted avg       0.81      0.83      0.80      1584

# %%
mygrid_test_predictions_xgb_robust = mygrid_xgb_robust.predict(X_test) 
class_report(mygrid_xgb_robust,y_test,mygrid_test_predictions_xgb_robust)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.84      0.96      0.90       420
#            2       0.41      0.15      0.22        73
#            3       0.60      0.33      0.43        36
#
#     accuracy                           0.81       529
#    macro avg       0.62      0.48      0.52       529
# weighted avg       0.76      0.81      0.77       529

# %%
precision_score(y_test,mygrid_test_predictions_xgb_robust, average="weighted")
# Out:
# 0.7641688186315567

# %%
recall_score(y_test,mygrid_test_predictions_xgb_robust, average="weighted")
# Out:
# 0.8090737240075614

# %%
f1_score(y_test,mygrid_test_predictions_xgb_robust, average="micro")
# Out:
# 0.8090737240075614

# %%
from sklearn.metrics import matthews_corrcoef

matthews_corrcoef(y_test, mygrid_test_predictions_xgb_robust) # for multiclass evaluation a score above 0.7 is considered good
# Out:
# 0.317552575689132

# %% [markdown]
# **Precision Recall Curve for Multiclass**

# %%
# Reference: https://stackoverflow.com/questions/56090541/how-to-plot-precision-and-recall-of-multiclass-classifier
from sklearn.multiclass import  OneVsRestClassifier
from sklearn.preprocessing import label_binarize
from sklearn.metrics import precision_recall_curve,roc_curve

y = label_binarize(y, classes=[1,2,3])
n_classes = y.shape[1]

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    random_state = 42)

clf_robust = OneVsRestClassifier(xgb.XGBClassifier(grow_policy='depthwise', 
                                            learning_rate=0.3, 
                                            max_depth=5, 
                                            max_leaves=5, 
                                            n_estimators=200, 
                                            tree_method='approx'))
clf_robust.fit(X_train, y_train)
X_test = X_test.astype(int)
# y_prediction_proba = clf.predict_proba(X_test) > 0.3
y_prediction_proba_xgb_robust = clf_robust.predict_proba(X_test)
# Out:
# [22:21:48] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [22:21:49] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [22:21:49] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
# For each class 
precision = dict()
recall = dict()

y_test = y_test
def precision_recall_plot(value,y_test):
    for i in range(n_classes):
        precision[i], recall[i], threshold = precision_recall_curve(y_test[:,i], 
                                                        value[:,i])
        plt.plot(precision[i],recall[i],lw=2, label= "class {}".format(i))


    plt.xlabel("precision")
    plt.ylabel("recall")
    plt.legend(loc="best")
    plt.title("Precision-recall curve of multiclass; dataset")
    plt.show()
    average_precision = average_precision_score(y_test,value, average='micro')
    print("Average precision score, micro-averaged over all classes: {:.3f}".format(average_precision))

# %%
precision_recall_plot(y_prediction_proba_xgb_robust,y_test)
# Out:
# Average precision score, micro-averaged over all classes: 0.936

# %%
fpr = dict()
tpr = dict()

def roc_curve_plot(value,y_test):
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:,i], 
                                                    value[:,i])
        plt.plot(fpr[i], tpr[i], lw=2, label= "class {}".format(i))

    plt.xlabel("false positive rate")
    plt.ylabel("true positive rate")
    plt.legend(loc="best")
    plt.title("ROC curve of multiclass; dataset")
    plt.show()
    roc_auc_scoring_macro_ovr = roc_auc_score(y_test,value, multi_class="OvR",average='macro')
    roc_auc_scoring_weighted_ovr = roc_auc_score(y_test,value, multi_class="OvR",average='weighted')
    print("AUC score using OvR, macro-averaged over all classes: {:.3f}\nWeighted-averaged over all classes: {:.3f}"
    .format(roc_auc_scoring_macro_ovr,roc_auc_scoring_weighted_ovr))

# %%
roc_curve_plot(y_prediction_proba_xgb_robust,y_test)
# Out:
# AUC score using OvR, macro-averaged over all classes: 0.953
# Weighted-averaged over all classes: 0.937

# %%
# This is for the training set
model= ['XGB_robust','Gradient Boosting Classifier_robust','KNN_robust']
prediction_score_robust= [mygrid_xgb_robust.best_score_,mygrid_further_robust.best_score_,mygrid_robust.best_score_]

model_comparison = {"model": model, "prediction_score": prediction_score_robust}
comparison_2 = pd.DataFrame(model_comparison)
scaler_compare = pd.concat([comparison,comparison_2],axis=0,ignore_index=True)

# %%
scaler_compare
# Out:
#                                  model  prediction_score
# 0                                  XGB          0.898107
# 1         Gradient Boosting Classifier          0.906625
# 2                                  KNN          0.895268
# 3                           XGB_robust          0.801577
# 4  Gradient Boosting Classifier_robust          0.801893
# 5                           KNN_robust          0.802208
